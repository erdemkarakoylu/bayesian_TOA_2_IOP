# %%
from pathlib import Path

import numpy as np
import pandas as pd
from scripts import data_loader

# %%
project_path = Path.cwd()
data_path = project_path / 'data'

# %%
oos_rrs = pd.read_csv(data_path / )
